# %%
# !pip install lightkurve

# %%
import lightkurve as lk
import matplotlib.pyplot as plt

# %%
TIC = 'TIC 172900988'  # TRAPPIST-1 system
sector_data = lk.search_lightcurve(TIC)
print(sector_data)
# Out:
# SearchResult containing 14 data products.
#
#  #     mission     year   author  exptime target_name distance
#                                      s                 arcsec
# --- -------------- ---- --------- ------- ----------- --------
#   0 TESS Sector 44 2021      SPOC     120   172900988      0.0
#   1 TESS Sector 45 2021      SPOC     120   172900988      0.0
#   2 TESS Sector 46 2021      SPOC     120   172900988      0.0
#   3 TESS Sector 47 2021      SPOC     120   172900988      0.0
#   4 TESS Sector 21 2020 TESS-SPOC    1800   172900988      0.0
#   5 TESS Sector 44 2021 TESS-SPOC     600   172900988      0.0
#   6 TESS Sector 45 2021 TESS-SPOC     600   172900988      0.0
#   7 TESS Sector 46 2021 TESS-SPOC     600   172900988      0.0
#   8 TESS Sector 47 2021 TESS-SPOC     600   172900988      0.0
#   9 TESS Sector 21 2020       QLP    1800   172900988      0.0
#  10 TESS Sector 44 2021       QLP     600   172900988      0.0
# ...

# %%
lc = sector_data[0].download()
# You have to put the number for sector_data[] you can choose your own number
lc.plot(linewidth= 0, marker = '.', color = 'pink', alpha = 1 )
# This is the default code but you can customize it if you want
# Out:
# <Axes: xlabel='Time - 2457000 [BTJD days]', ylabel='Flux [$\\mathrm{e^{-}\\,s^{-1}}$]'>

# %%
lc_norm = lc.normalize()

# Haha you thought this was going to be easy, continue from here to normalize the above data

# %% [markdown]
# **Dear Participants,**
#
# Using ***AI*** for assignment submission is strictly prohibited. You can use
# AI to practice and learn but no AI for assignments. See you on the next doubt session make sure to save doubts!
